# %%
# Import libraries
import numpy as np
import cv2 as cv
import datetime

# open the video
vid = cv.VideoCapture('Videos/dog.mp4')

# Process until end.
while(vid.isOpened()):
    ret, frame = vid.read()

    if ret:
        # describe the type of
        # font you want to display
        # font = cv2.FONT_HERSHEY_SCRIPT_COMPLEX
        font = cv.FONT_HERSHEY_SIMPLEX

        # Get date and time and
        # save it inside a variable
        dt = str(datetime.datetime.now())

        # put the dt variable over the
        # video frame
        frame = cv.putText(frame, dt,(10, 100),font, 1,(210, 155, 155),4, cv.LINE_8)
        
        # show the video
        cv.imshow('frame', frame)

        key = cv.waitKey(1)
        
        # define the key to
        # close the window
        if key == 'q' or key == 27:
            break
    else:
        
        break
        
        
# release the vid object
vid.release()

# close all the opened windows.
cv.destroyAllWindows()

# %%
from datetime import datetime
# Open the Camera
cap = cv.VideoCapture(0)
while True:
    ret, img = cap.read()
    # Put current DateTime on each frame
    font = cv.FONT_HERSHEY_SIMPLEX
    cv.putText(img,str(datetime.now()),(10,30), font, 1,(255,255,255),2,cv.LINE_AA)
    # Display the image
    cv.imshow('a',img)
    # wait for keypress
    k = cv.waitKey(10)
    if k == ord('q'):
        break
cap.release()
cv.destroyAllWindows()

# %%
def drawCircle(event, x, y, flags, param):
 
    if event == cv.EVENT_MOUSEMOVE:
#         print('({}, {})'.format(x, y))
 
        imgCopy = img.copy()
        cv.circle(imgCopy, (x, y), 10, (255, 0, 0), -1)
 
        cv.imshow('image', imgCopy)
 
 
img = cv.imread('Photos/park.jpg')
cv.imshow('image', img)
 
cv.setMouseCallback('image', drawCircle)
 
cv.waitKey(0)
cv.destroyAllWindows()

# %%
events = [i for i in dir(cv) if 'EVENT' in i]
for i in events:
    print(i)
# Out:
# EVENT_FLAG_ALTKEY
# EVENT_FLAG_CTRLKEY
# EVENT_FLAG_LBUTTON
# EVENT_FLAG_MBUTTON
# EVENT_FLAG_RBUTTON
# EVENT_FLAG_SHIFTKEY
# EVENT_LBUTTONDBLCLK
# EVENT_LBUTTONDOWN
# EVENT_LBUTTONUP
# EVENT_MBUTTONDBLCLK
# EVENT_MBUTTONDOWN
# EVENT_MBUTTONUP
# EVENT_MOUSEHWHEEL
# EVENT_MOUSEMOVE
# EVENT_MOUSEWHEEL
# EVENT_RBUTTONDBLCLK
# EVENT_RBUTTONDOWN
# EVENT_RBUTTONUP

# %%
def printCoordinate(event, x, y, flags, params):
    #print(x,',',y)
    if event == cv.EVENT_LBUTTONDOWN:
        cv.circle(img, (x,y), 3, (255,255,255), -1)
        strXY = '('+str(x)+','+str(y)+')'
        font = cv.FONT_HERSHEY_PLAIN
        cv.putText(img, strXY, (x+10, y+10), font, 1, (255,255,255))
        cv.imshow('Image',img)


img = np.zeros((800,800,3), dtype=np.uint8)
# cv.namedWindow("image") 
cv.imshow('Image', img)
cv.setMouseCallback('Image', printCoordinate)


cv.waitKey(0) 
cv.destroyAllWindows()

# %%
prevX, prevY = -1,-1
def printCoordinate(event, x, y, flags, params):
    #print(x,',',y)
    global prevX, prevY
    
    if event == cv.EVENT_LBUTTONDOWN:
        cv.circle(img, (x,y), 3, (255,255,255), -1)
        strXY = '('+str(x)+','+str(y)+')'
        font = cv.FONT_HERSHEY_PLAIN
        cv.putText(img, strXY, (x+10, y+10), font, 1, (255,255,255))
        #cv.imshow('Image',img)
        
        if prevX == -1 and prevY == -1:
            prevX, prevY = x,y
        else:
            cv.line(img, (prevX, prevY), (x,y), (0,255,0), 5)
            prevX, prevY = -1, -1
        cv.imshow('Image', img)    


img = np.zeros((800,800,3), dtype=np.uint8)
# cv.namedWindow("image") 
cv.imshow('Image', img)
cv.setMouseCallback('Image', printCoordinate)


cv.waitKey(0) 
cv.destroyAllWindows()
