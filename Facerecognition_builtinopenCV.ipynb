# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
people = []
for i in os.listdir(r'C:\Users\Riyaz\Desktop\DS & ML\Open CV\Faces\train'):
    people.append(i)
    
# print(people)
diR = r'C:\Users\Riyaz\Desktop\DS & ML\Open CV\Faces\train'

haar_cascade = cv.CascadeClassifier('frontface.xml')

features = []
labels = []

def create_train():
    for person in people:
        path = os.path.join(diR, person)
        label = people.index(person)
        
        for img in os.listdir(path):
            img_path = os.path.join(path, img)
            
            img_array = cv.imread(img_path)
            gray = cv.cvtColor(img_array, cv.COLOR_BGR2GRAY)
            
            face_rect =  haar_cascade.detectMultiScale(gray, scaleFactor = 1.1, minNeighbors = 4)
            
            for (x,y,w,h) in face_rect:
                faces_roi = gray[y:y+h, x:x+w]
                features.append(faces_roi)
                labels.append(label)
                
create_train()         
# print(features)
# print(len(labels))

# print(type(features))
# print(type(labels))

face_recognizer = cv.face.LBPHFaceRecognizer_create()

# train recognizer on feaures list and labels list

features = np.array(features, dtype = 'object')
labels = np.array(labels)

face_recognizer.train(features, labels)


face_recognizer.save('face_trained.yml')
np.save('features.npy', features)
np.save('labels.npy', labels)
# Out:
# [array([[100,  68,   1, ...,  16,  22,  23],
#        [ 90,  78,   2, ...,  13,   7,  11],
#        [ 92,  56,   1, ...,   3,   2,   8],
#        ...,
#        [ 48,  24,  12, ...,  24,  24,  19],
#        [ 28,  17,  13, ...,  32,  22,  22],
#        [ 11,  14,  17, ...,  25,  22,  22]], dtype=uint8), array([[18, 17, 18, ...,  1,  1,  5],
#        [19, 18, 19, ...,  1,  2,  5],
#        [20, 19, 19, ...,  2,  2,  5],
#        ...,
#        [54, 53, 53, ...,  7,  8,  8],
#        [56, 55, 53, ...,  7,  7,  7],
#        [56, 55, 54, ...,  7,  7,  7]], dtype=uint8), array([[ 21,   6,  18, ...,  32,  30,  25],
#        [ 12,   7,  20, ...,  31,  28,  24],
#        [ 15,  10,  20, ...,  33,  29,  23],
#        ...,
#        [105, 106,  76, ...,  21,  22,  23],
#        [117,  99,  83, ...,  21,  22,  23],
#        [113, 113,  88, ...,  22,  23,  24]], dtype=uint8), array([[ 94,  65,  45, ...,  86,  83,  89],
#        [ 95,  65,  46, ..., 104,  93,  78],
#        [ 99,  71,  50, ...,  88,  78,  84],
#        ...,
#        [132, 130, 128, ..., 153,  91,  75],
#        [137, 134, 127, ..., 136,  76,  80],
#        [136, 133, 127, ..., 131,  81,  89]], dtype=uint8), array([[ 29,  52,  64, ..., 101, 114, 122],
#        [ 40,  60,  66, ..., 105, 123, 124],
#        [ 53,  65,  64, ..., 110, 122, 125],
#        ...,
#        [196, 186, 164, ..., 235, 213, 158],
#        [195, 162, 182, ..., 248, 201, 182],
#        [183, 189, 184, ..., 252, 213, 199]], dtype=uint8), array([[227, 227, 227, ...,  38,  28, 124],
#        [228, 227, 226, ...,  31,  34,  58],
#        [227, 226, 225, ...,  25,  37,  34],
#        ...,
#        [222, 222, 222, ..., 182, 180, 179],
#        [222, 222, 222, ..., 194, 192, 190],
#        [222, 222, 221, ..., 211, 190, 196]], dtype=uint8), array([[  9,  10,  13, ...,   7,   5,  35],
#        [  9,   2,   2, ...,   6,  16,  30],
#        [  7,   0,   2, ...,  11,   4,   8],
#        ...,
#        [220, 224,  95, ...,  53,  52, 101],
#        [216, 230, 170, ..., 116,  90, 106],
#        [222, 193, 177, ..., 129,  96, 104]], dtype=uint8), array([[197, 180, 165, ...,  41,  50,  95],
#        [159, 132, 117, ...,  45,  50, 102],
#        [114, 107, 108, ...,  53,  51, 105],
#        ...,
#        [216, 197, 122, ..., 239, 237, 235],
#        [224, 212, 167, ..., 237, 235, 233],
#        [231, 227, 217, ..., 238, 237, 228]], dtype=uint8), array([[ 73,  76,  75, ...,  91,  74,  63],
#        [ 72,  75,  74, ...,  62,  99,  72],
#        [ 69,  71,  73, ...,  43,  90,  72],
#        ...,
#        [ 54,  53,  59, ..., 181, 183, 185],
#        [ 56,  56,  59, ..., 183, 185, 186],
#        [ 57,  56,  59, ..., 185, 187, 187]], dtype=uint8), array([[ 13,  11,   8, ..., 102, 102,  96],
#        [ 11,  10,   8, ..., 113,  99,  97],
#        [  8,   7,   7, ..., 100, 105, 104],
#        ...,
#        [180, 233, 133, ..., 175, 134, 124],
#        [179, 203, 229, ...,  60, 149, 148],
#        [211, 195, 216, ...,   1,   9,  71]], dtype=uint8), array([[ 69,  36,  57, ..., 206, 206, 207],
#        [ 66,  39,  55, ..., 206, 206, 207],
#        [ 65,  42,  47, ..., 206, 206, 207],
#        ...,
#        [ 53,  45,  47, ..., 140, 140, 141],
#        [ 54,  48,  44, ..., 137, 137, 138],
#        [ 51,  56,  46, ..., 135, 135, 136]], dtype=uint8), array([[232, 232, 232, ...,  82,  85,  77],
#        [232, 232, 232, ...,  83,  86,  82],
#        [232, 232, 232, ...,  85,  88,  85],
#        ...,
#        [237, 237, 237, ...,  81,  78,  84],
#        [237, 237, 237, ...,  81,  80,  83],
#        [237, 237, 237, ...,  83,  83,  82]], dtype=uint8), array([[ 28,  28,  29, ...,  30,  30,  30],
#        [ 28,  29,  29, ...,  31,  31,  31],
#        [ 29,  29,  29, ...,  31,  31,  31],
#        ...,
#        [ 29,  31,  32, ...,  39,  48, 104],
#        [ 29,  31,  32, ...,  39,  47,  38],
#        [ 29,  30,  31, ...,  39,  42,  29]], dtype=uint8), array([[ 20,  12,  14, ...,  12,  20,  14],
#        [ 20,  24,  21, ...,  12,   2,  17],
#        [ 23,  22,  20, ...,  13,  63,  70],
#        ...,
#        [ 12,  19,  18, ..., 227, 212, 102],
#        [ 36,  14,  15, ..., 232, 174,  39],
#        [ 73,  20,  13, ..., 209,  85,  18]], dtype=uint8), array([[ 5,  8, 11, ...,  0,  0,  0],
#        [ 5,  8, 11, ...,  0,  0,  0],
#        [ 5,  8, 12, ...,  1,  0,  0],
#        ...,
#        [82, 75, 75, ..., 17, 24, 65],
#        [88, 74, 76, ..., 35, 45, 85],
#        [91, 80, 86, ..., 52, 58, 79]], dtype=uint8), array([[ 0,  0,  0, ..., 62, 42, 15],
#        [ 0,  0,  0, ..., 62, 46, 24],
#        [ 0,  0,  0, ..., 71, 63, 60],
#        ...,
#        [ 0,  1,  1, ...,  0,  1,  1],
#        [ 5,  2,  2, ...,  7,  3,  1],
#        [ 6, 11,  2, ...,  3,  2, 11]], dtype=uint8), array([[153, 162, 163, ..., 101,  68,  19],
#        [161, 152, 146, ..., 100,  54,  19],
#        [155, 140, 127, ..., 113,  43,  17],
#        ...,
#        [ 18,  19,  15, ...,  74,  75,  76],
#        [ 18,  11,  12, ...,  61,  62,  67],
#        [ 18,  10,  14, ...,  47,  46,  45]], dtype=uint8), array([[ 35,  34,  37, ..., 208, 145, 101],
#        [ 34,  32,  36, ..., 187, 168,  46],
#        [ 34,  32,  34, ..., 177, 216, 141],
#        ...,
#        [ 26,  28,  60, ...,  27,  28,  35],
#        [  8,   7,  16, ...,  21,  44,  26],
#        [ 16,   3,   0, ...,  33,  26,  38]], dtype=uint8), array([[109, 107, 104, ...,  40,  40,  39],
#        [109, 108, 107, ...,  39,  37,  34],
#        [109, 108, 108, ...,  40,  38,  36],
#        ...,
#        [ 82,  97,  84, ..., 254, 235, 188],
#        [104,  89,  81, ..., 251, 253, 211],
#        [121,  81, 100, ..., 239, 253, 247]], dtype=uint8), array([[ 62,  65,  64, ...,  41,  33,  19],
#        [ 62,  63,  69, ...,  38,  29,  18],
#        [ 67,  67,  67, ...,  34,  25,  25],
#        ...,
#        [104, 103, 106, ...,  45,  45,  45],
#        [104, 104, 106, ...,  43,  44,  44],
#        [105, 107, 109, ...,  43,  44,  44]], dtype=uint8), array([[217, 226, 227, ..., 217, 218, 220],
#        [217, 225, 223, ..., 219, 219, 220],
#        [216, 223, 217, ..., 221, 220, 220],
#        ...,
#        [ 36,  39,  39, ...,  40,  39,  38],
#        [ 36,  40,  39, ...,  41,  40,  40],
#        [ 35,  39,  37, ...,  41,  43,  43]], dtype=uint8), array([[14, 15, 15, ..., 12, 12, 12],
#        [14, 15, 15, ..., 12, 12, 12],
#        [13, 15, 14, ..., 12, 12, 12],
#        ...,
#        [19, 17, 16, ..., 23, 22, 20],
#        [22, 14, 15, ..., 20, 21, 21],
#        [13, 13, 15, ..., 21, 20, 20]], dtype=uint8), array([[ 35,  37,  34, ...,  82,  92,  74],
#        [ 32,  38,  36, ...,  69,  59,  59],
#        [ 28,  31,  30, ...,  68,  50,  60],
#        ...,
#        [ 19,  21,  25, ..., 136, 139, 144],
#        [ 22,  21,  24, ..., 138, 143, 148],
#        [ 27,  22,  25, ..., 141, 150, 154]], dtype=uint8), array([[ 23,  22,  23, ...,  74,  68,  58],
#        [ 23,  23,  24, ...,  69,  63,  54],
#        [ 23,  24,  25, ...,  63,  58,  50],
#        ...,
#        [116, 116, 127, ...,  23,  21,  18],
#        [119, 115, 124, ...,  23,  21,  18],
#        [121, 115, 122, ...,  23,  21,  18]], dtype=uint8), array([[231, 232, 124, ..., 233, 239, 236],
#        [222, 199, 116, ..., 203, 237, 238],
#        [199, 150, 111, ..., 171, 235, 240],
#        ...,
#        [154, 120,  88, ..., 221, 221, 221],
#        [ 31,  20,  15, ..., 221, 221, 221],
#        [ 19,  23,  20, ..., 220, 221, 221]], dtype=uint8), array([[118,  65,  43, ...,  41,  34,  32],
#        [105,  73,  68, ...,  29,  32,  37],
#        [ 85,  86,  96, ...,  14,  28,  40],
#        ...,
#        [108, 109,  98, ...,  38,  37,  35],
#        [100, 103,  98, ...,  44,  41,  36],
#        [ 87,  92, 104, ...,  46,  41,  34]], dtype=uint8), array([[230, 207, 188, ...,  98, 127, 133],
#        [228, 218, 214, ...,  97, 121, 141],
#        [227, 232, 241, ...,  97, 114, 147],
#        ...,
#        [255, 255, 253, ..., 255, 251, 253],
#        [239, 239, 254, ..., 181, 255, 239],
#        [255, 255, 255, ...,  83, 182, 254]], dtype=uint8), array([[ 16,  18,  18, ..., 144, 135, 129],
#        [ 17,  19,  20, ..., 138, 139, 139],
#        [ 18,  20,  21, ..., 121, 136, 141],
#        ...,
#        [128, 108, 168, ..., 133, 107, 127],
#        [137, 114, 192, ..., 109, 108, 121],
#        [142, 121, 198, ...,  97, 104, 124]], dtype=uint8), array([[ 48,  26,  30, ...,  71,  85,  85],
#        [ 34,  32,  32, ...,  78,  85,  79],
#        [ 33,  37,  27, ...,  66,  63,  88],
#        ...,
#        [104,  99,  98, ..., 199, 200, 198],
#        [108, 100,  97, ..., 199, 199, 198],
#        [113, 104,  98, ..., 199, 199, 198]], dtype=uint8), array([[  4,   2,   2, ..., 169, 168, 158],
#        [  2,   1,   1, ..., 155, 148, 159],
#        [  2,   4,   7, ..., 161, 156, 165],
#        ...,
#        [ 10,  15,  15, ...,   2,   2,   1],
#        [ 11,  17,  15, ...,   1,   2,   3],
#        [  6,  18,  15, ...,   2,   1,   2]], dtype=uint8), array([[120, 115, 112, ...,  28,  24,  25],
#        [120, 115, 112, ...,  27,  25,  26],
#        [120, 115, 112, ...,  26,  27,  27],
#        ...,
#        [121, 123, 124, ...,  29,  29,  29],
#        [120, 121, 124, ...,  28,  27,  28],
#        [119, 120, 124, ...,  28,  29,  29]], dtype=uint8), array([[46, 41, 48, ..., 29, 29, 29],
#        [36, 53, 63, ..., 29, 29, 29],
#        [41, 54, 63, ..., 30, 29, 28],
#        ...,
#        [30, 28, 24, ..., 12, 11, 11],
#        [29, 29, 27, ..., 24,  8,  7],
#        [29, 28, 28, ..., 25, 10, 11]], dtype=uint8), array([[  9,   1,   9, ..., 124, 158, 172],
#        [  8,   2,   9, ..., 164, 195, 128],
#        [  8,   4,  21, ..., 158, 143, 152],
#        ...,
#        [ 12,   8,  42, ...,   2,   1,   1],
#        [ 11,   8,  28, ...,  16,   7,   1],
#        [  4,  26,  13, ...,   2,  18,   0]], dtype=uint8), array([[133,  91,  23, ...,   3,   1,   3],
#        [131, 116,  51, ...,   4,   2,   3],
#        [126, 135,  78, ...,   6,   4,   2],
#        ...,
#        [ 30,  32,  27, ...,  16,  13,  12],
#        [ 17,  20,  26, ...,  18,  15,  13],
#        [ 24,  33,  30, ...,  16,  15,  14]], dtype=uint8), array([[244, 244, 244, ..., 247, 247, 247],
#        [243, 243, 243, ..., 246, 246, 246],
#        [246, 246, 246, ..., 246, 246, 246],
#        ...,
#        [254, 254, 254, ...,  35,  38,  34],
#        [254, 254, 254, ..., 103,  39,  31],
#        [253, 253, 253, ..., 209,  39,  41]], dtype=uint8), array([[250, 250, 250, ...,  39,  49,  53],
#        [250, 250, 250, ...,  41,  45,  49],
#        [250, 250, 250, ...,  40,  46,  46],
#        ...,
#        [250, 250, 250, ..., 250, 250, 250],
#        [250, 250, 250, ..., 250, 250, 250],
#        [250, 250, 250, ..., 250, 250, 250]], dtype=uint8), array([[66, 61, 45, ..., 96, 81, 51],
#        [47, 67, 34, ..., 72, 86, 63],
#        [55, 57, 23, ..., 84, 86, 59],
#        ...,
#        [69, 70, 56, ..., 86, 95, 63],
#        [52, 59, 89, ..., 90, 89, 72],
#        [56, 80, 72, ..., 91, 96, 87]], dtype=uint8), array([[ 54,  57,  62, ...,  67,  60,  53],
#        [ 55,  53,  60, ...,  62,  59,  56],
#        [ 55,  48,  50, ...,  60,  57,  60],
#        ...,
#        [160, 172, 157, ...,  74,  69,  63],
#        [146, 147, 148, ...,  64,  69,  69],
#        [176, 170, 161, ...,  57,  62,  66]], dtype=uint8), array([[ 37,  31,  25, ..., 242, 245, 242],
#        [ 37,  28,  21, ..., 241, 246, 242],
#        [ 35,  30,  20, ..., 239, 243, 244],
#        ...,
#        [ 19,  14,  19, ..., 230, 230, 230],
#        [ 21,  13,  23, ..., 230, 230, 230],
#        [ 17,  17,  18, ..., 229, 230, 230]], dtype=uint8), array([[ 36,  42,  53, ..., 203, 203, 203],
#        [ 39,  43,  45, ..., 204, 203, 203],
#        [ 32,  21,  56, ..., 204, 203, 203],
#        ...,
#        [ 67,  78, 106, ..., 209, 209, 210],
#        [ 67,  78, 102, ..., 209, 210, 210],
#        [ 69,  79, 100, ..., 210, 210, 210]], dtype=uint8), array([[ 17,  22,  17, ...,   0,   0,   6],
#        [ 23,  28,  21, ...,   0,   3,   5],
#        [ 27,  33,  30, ...,   0,   4,   1],
#        ...,
#        [133, 128, 131, ...,  36,  36,  35],
#        [135, 131, 131, ...,  37,  36,  35],
#        [138, 135, 132, ...,  36,  35,  35]], dtype=uint8), array([[28, 39, 24, ..., 29, 29, 28],
#        [31, 32, 11, ..., 28, 28, 28],
#        [15, 44, 57, ..., 26, 26, 26],
#        ...,
#        [ 4,  4,  2, ..., 30, 32, 34],
#        [ 5,  1,  0, ..., 27, 29, 32],
#        [ 0,  0,  0, ..., 24, 26, 29]], dtype=uint8), array([[113, 111, 111, ...,  41,  95, 114],
#        [112, 113, 124, ...,  39,  94, 111],
#        [111, 111, 110, ...,  24,  64,  92],
#        ...,
#        [ 89,  78,  71, ...,   3,   1,   3],
#        [ 86,  77,  70, ...,   7,   5,   7],
#        [ 85,  79,  71, ...,   3,   1,   8]], dtype=uint8), array([[254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 253, ..., 254, 254, 254],
#        [254, 250, 247, ..., 254, 254, 254],
#        ...,
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254]], dtype=uint8), array([[ 52,  54,  70, ...,  16,  23,  22],
#        [ 57,  68,  77, ...,  21,  19,  24],
#        [ 52,  63,  76, ...,  30,  37,  40],
#        ...,
#        [140, 188, 238, ...,  48,   7,  12],
#        [178, 138, 253, ...,  21,   1,  10],
#        [214,  96, 183, ...,   2,   5,   5]], dtype=uint8), array([[255, 255, 255, ..., 177, 177, 175],
#        [255, 255, 255, ..., 178, 177, 175],
#        [255, 255, 255, ..., 179, 177, 173],
#        ...,
#        [255, 255, 255, ..., 122, 123, 124],
#        [255, 255, 255, ..., 131, 134, 145],
#        [255, 255, 255, ..., 142, 153, 170]], dtype=uint8), array([[254, 253, 253, ..., 254, 254, 253],
#        [253, 252, 252, ..., 255, 255, 254],
#        [253, 252, 251, ..., 255, 255, 254],
#        ...,
#        [215, 215, 215, ..., 192, 195, 195],
#        [215, 215, 215, ..., 194, 196, 197],
#        [215, 215, 215, ..., 198, 193, 193]], dtype=uint8), array([[ 57,  49,  45, ...,  42,  44,  53],
#        [ 54,  51,  52, ...,  47,  49,  52],
#        [ 61,  58,  54, ...,  46,  46,  45],
#        ...,
#        [251, 251, 251, ..., 251, 251, 251],
#        [251, 251, 251, ..., 251, 251, 251],
#        [251, 251, 251, ..., 251, 251, 251]], dtype=uint8), array([[ 91, 208, 225, ..., 116,  41,  12],
#        [ 58, 178, 228, ..., 119,  50,  13],
#        [ 43, 138, 221, ..., 122,  57,  11],
#        ...,
#        [ 30,  30,  31, ..., 202,  78,  31],
#        [ 30,  30,  31, ..., 197,  73,  30],
#        [ 29,  30,  31, ..., 191,  66,  29]], dtype=uint8), array([[234, 235, 230, ...,  40,  63, 185],
#        [232, 234, 229, ...,  42,  37, 118],
#        [237, 235, 224, ...,  42,  39,  65],
#        ...,
#        [239, 241, 241, ..., 239, 246, 248],
#        [239, 240, 240, ..., 245, 243, 244],
#        [239, 240, 240, ..., 245, 243, 245]], dtype=uint8), array([[229, 229, 229, ..., 226, 226, 225],
#        [229, 229, 229, ..., 226, 226, 225],
#        [228, 229, 230, ..., 226, 226, 225],
#        ...,
#        [ 34,  19,  23, ..., 223, 227, 226],
#        [ 53,  15,  25, ..., 224, 226, 226],
#        [ 83,  14,  21, ..., 229, 229, 226]], dtype=uint8), array([[ 26,  18,  20, ..., 180, 180, 180],
#        [ 12,   4,  22, ..., 182, 179, 180],
#        [  9,   7,  18, ..., 181, 179, 179],
#        ...,
#        [ 64,  56,  59, ..., 248, 249, 249],
#        [ 68,  51,  62, ..., 247, 249, 249],
#        [ 63,  57,  61, ..., 248, 252, 250]], dtype=uint8), array([[255, 255, 255, ..., 254, 255, 255],
#        [255, 255, 250, ..., 254, 254, 255],
#        [255, 255, 255, ..., 254, 255, 255],
#        ...,
#        [255, 255, 252, ...,  37,  29,   6],
#        [255, 255, 254, ...,  19,  31,  29],
#        [255, 255, 255, ...,  29,  26,  29]], dtype=uint8), array([[119, 112, 113, ...,  27,  27,  28],
#        [119, 112, 113, ...,  27,  26,  28],
#        [120, 114, 114, ...,  26,  28,  28],
#        ...,
#        [121, 124, 127, ...,  29,  29,  29],
#        [121, 123, 127, ...,  29,  29,  29],
#        [120, 123, 127, ...,  30,  29,  30]], dtype=uint8), array([[251, 251, 251, ..., 173, 153, 134],
#        [251, 251, 251, ..., 172, 152, 133],
#        [251, 251, 251, ..., 167, 151, 138],
#        ...,
#        [ 33,  45,  56, ..., 189, 177, 127],
#        [ 33,  39,  41, ..., 185, 179, 145],
#        [ 23,  26,  28, ..., 182, 193, 134]], dtype=uint8), array([[150, 148, 133, ..., 103, 108, 127],
#        [150, 153, 133, ...,  98,  99, 111],
#        [154, 159, 131, ...,  89,  88, 104],
#        ...,
#        [196, 213, 222, ..., 114, 138, 167],
#        [203, 216, 225, ..., 143, 104, 151],
#        [198, 216, 202, ..., 159, 135, 119]], dtype=uint8), array([[167, 164, 158, ..., 189, 185, 185],
#        [152, 154, 157, ..., 178, 184, 198],
#        [147, 156, 165, ..., 178, 181, 188],
#        ...,
#        [207, 209, 211, ..., 239, 230, 236],
#        [205, 204, 201, ..., 234, 231, 229],
#        [199, 190, 182, ..., 223, 230, 221]], dtype=uint8), array([[219, 219, 219, ...,  12,  11,  11],
#        [220, 220, 220, ...,  13,  13,  12],
#        [218, 218, 219, ...,  14,  13,  12],
#        ...,
#        [209, 199, 179, ...,  41,  37, 157],
#        [206, 203, 180, ...,  35,  35, 102],
#        [200, 206, 182, ...,  34,  47,  61]], dtype=uint8), array([[149, 133, 111, ..., 230, 238, 232],
#        [178, 175, 171, ..., 227, 240, 233],
#        [194, 192, 184, ..., 215, 241, 232],
#        ...,
#        [173, 106, 148, ..., 172, 181, 179],
#        [107, 121,  94, ..., 138, 165, 177],
#        [134, 123, 100, ..., 144, 166, 174]], dtype=uint8), array([[132, 102,  96, ..., 193, 213, 228],
#        [140, 142, 158, ..., 240, 249, 248],
#        [158, 150, 180, ..., 250, 249, 251],
#        ...,
#        [248, 248, 248, ..., 156, 168, 168],
#        [247, 247, 247, ..., 141, 162, 180],
#        [248, 247, 246, ..., 116, 138, 182]], dtype=uint8), array([[ 39,  32,  30, ..., 112,  96,  97],
#        [ 28,  25,  74, ..., 107, 112,  98],
#        [106, 138, 195, ..., 102, 108, 120],
#        ...,
#        [244, 244, 244, ..., 237, 238, 242],
#        [247, 245, 246, ..., 217, 242, 234],
#        [247, 243, 244, ..., 124, 210, 242]], dtype=uint8), array([[193, 210, 221, ...,  93, 102, 119],
#        [184, 215, 207, ...,  77,  85, 101],
#        [169, 210, 200, ...,  86,  84,  87],
#        ...,
#        [116,  68,  77, ...,  91, 103, 123],
#        [104,  75,  84, ...,  97,  98, 127],
#        [ 77,  73,  42, ..., 116, 129, 126]], dtype=uint8), array([[ 72,  98,  83, ..., 202, 210, 165],
#        [ 90,  85,  94, ..., 202, 190,  88],
#        [ 81,  96,  91, ..., 202, 223,  27],
#        ...,
#        [ 85,  30,  43, ...,  80,  91, 125],
#        [111,  70,  10, ...,  86,  90, 115],
#        [101,  86,  22, ...,  93,  99, 109]], dtype=uint8), array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 254, 255, 255],
#        ...,
#        [248, 248, 247, ...,  28, 112,  94],
#        [248, 247, 247, ...,  17,  23, 106],
#        [248, 247, 247, ...,   6,  13,  63]], dtype=uint8), array([[ 49,  47,  48, ..., 149, 144, 123],
#        [ 57,  49,  49, ..., 147, 135, 131],
#        [ 66,  52,  46, ..., 157, 144, 124],
#        ...,
#        [ 91,  74,  77, ..., 146, 122, 157],
#        [ 70,  52,  91, ..., 142, 128, 159],
#        [ 44,  75, 120, ..., 149, 135, 161]], dtype=uint8), array([[ 25,  25,  25, ..., 207, 193, 168],
#        [ 25,  25,  25, ..., 199, 206, 177],
#        [ 25,  25,  25, ..., 188, 209, 198],
#        ...,
#        [ 42,  42,  41, ..., 148,  98,  88],
#        [ 42,  43,  44, ..., 156,  96,  88],
#        [ 30,  31,  33, ..., 147,  98, 114]], dtype=uint8), array([[203, 195, 203, ...,   1,   1,   1],
#        [204, 197, 207, ...,   1,   2,   1],
#        [208, 192, 202, ...,   7,   0,   1],
#        ...,
#        [195, 190, 193, ..., 116,  64,  39],
#        [200, 190, 198, ...,  86,  36,  14],
#        [200, 193, 196, ...,  21,   5,   2]], dtype=uint8), array([[117,  98,  83, ...,  48,  34,  27],
#        [119, 106,  97, ...,  54,  47,  25],
#        [107, 110, 111, ...,  43,  41,  40],
#        ...,
#        [ 69,  80,  82, ..., 119, 130, 128],
#        [ 93,  97,  97, ...,  77,  83,  83],
#        [ 96, 124, 126, ...,  74,  63,  66]], dtype=uint8), array([[104, 125, 218, ...,  14,  12,  11],
#        [125, 122, 162, ...,  16,  15,  12],
#        [142, 136, 144, ...,  17,  16,  12],
#        ...,
#        [ 67,  34,  38, ...,   9,  10,   7],
#        [ 58,  44,  29, ...,   6,   9,   9],
#        [ 53,  65,  58, ...,   6,   7,   8]], dtype=uint8), array([[  8,   6,   5, ...,  46,  44,  43],
#        [  8,   5,   4, ...,  47,  46,  45],
#        [  6,   5,   3, ...,  47,  47,  47],
#        ...,
#        [165, 184, 187, ..., 173, 210,  63],
#        [159, 155, 172, ..., 101, 197, 109],
#        [167, 134, 167, ...,  43, 106, 115]], dtype=uint8), array([[252, 236, 224, ..., 136, 131, 125],
#        [237, 255, 228, ..., 126, 132, 130],
#        [236, 255, 218, ..., 130, 131, 129],
#        ...,
#        [245, 246, 254, ..., 142, 184, 210],
#        [246, 252, 255, ..., 129, 144, 199],
#        [247, 255, 255, ..., 128, 117, 166]], dtype=uint8), array([[206, 195, 171, ..., 192, 192, 193],
#        [200, 189, 176, ..., 188, 189, 191],
#        [191, 178, 175, ..., 187, 188, 191],
#        ...,
#        [138, 187, 203, ..., 228, 211, 213],
#        [127, 166, 203, ..., 232, 214, 204],
#        [123, 147, 197, ..., 232, 221, 201]], dtype=uint8), array([[206, 209, 213, ..., 179, 186, 195],
#        [207, 211, 213, ..., 197, 195, 193],
#        [218, 223, 215, ..., 232, 225, 213],
#        ...,
#        [154, 167, 180, ..., 163, 165, 168],
#        [132, 172, 192, ..., 145, 144, 152],
#        [142, 170, 194, ..., 148, 141, 137]], dtype=uint8), array([[228, 230, 204, ..., 137, 113, 123],
#        [212, 222, 239, ..., 134, 107, 119],
#        [203, 198, 192, ..., 134,  99, 128],
#        ...,
#        [165, 165, 172, ..., 159, 110, 113],
#        [165, 157, 140, ..., 128, 174, 192],
#        [166, 156, 169, ..., 235, 230, 229]], dtype=uint8), array([[127, 130, 127, ..., 189, 168, 163],
#        [120, 125, 122, ..., 191, 167, 146],
#        [122, 120, 117, ..., 176, 163, 161],
#        ...,
#        [  5,   4,   3, ..., 154, 111,   7],
#        [ 14,   9,   7, ..., 208, 171,  30],
#        [  8,   3,   2, ..., 178,  84,   5]], dtype=uint8), array([[ 80,  82,  70, ..., 226, 226, 226],
#        [ 85,  67,  55, ..., 227, 228, 228],
#        [ 87,  45,  48, ..., 227, 228, 229],
#        ...,
#        [106, 113, 128, ..., 236, 236, 233],
#        [102, 119, 125, ..., 236, 235, 233],
#        [ 96, 123, 124, ..., 236, 235, 232]], dtype=uint8), array([[17,  2, 14, ..., 25, 24, 25],
#        [12,  1, 14, ..., 28, 27, 27],
#        [ 9,  1, 12, ..., 33, 31, 29],
#        ...,
#        [ 2,  4,  3, ..., 31, 32, 20],
#        [ 3,  2,  0, ..., 27, 23, 21],
#        [ 3,  2,  1, ..., 31, 28, 29]], dtype=uint8), array([[  3,   6,   6, ...,   6,   6,  37],
#        [  3,   3,   3, ...,   5,  15,  22],
#        [  2,   5,  11, ...,   3,   9,  21],
#        ...,
#        [ 60,  57,  55, ...,  84,  63,  56],
#        [ 83, 120,  79, ...,  74, 100, 121],
#        [ 78, 142, 132, ..., 117, 133, 141]], dtype=uint8), array([[135, 135, 135, ...,  22,  23,  26],
#        [165, 185, 183, ...,  22,  23,  28],
#        [145, 159, 166, ...,  19,  19,  25],
#        ...,
#        [  7,   8,   8, ...,   9,   6,   7],
#        [  7,   7,   8, ...,   6,   6,   7],
#        [  7,   7,   7, ...,   4,   5,   7]], dtype=uint8), array([[105, 106, 117, ...,  34,  45,  37],
#        [107, 104, 111, ...,  27,  38,  59],
#        [108, 100,  98, ...,  30,  37,  52],
#        ...,
#        [ 21,  17,  16, ...,  25,  28,  37],
#        [ 28,  14,   9, ...,  37,  19,  31],
#        [ 28,  11,  10, ...,  38,  32,  29]], dtype=uint8), array([[ 32,  31,  36, ..., 166, 187, 199],
#        [ 35,  38,  36, ..., 165, 189, 206],
#        [ 38,  47,  41, ..., 154, 171, 188],
#        ...,
#        [ 73,  71,  67, ...,  66,  75,  46],
#        [ 76,  79,  70, ...,  56,  83,  56],
#        [ 67,  85,  79, ...,  47,  85,  58]], dtype=uint8), array([[ 55,  60,  55, ..., 233, 233, 230],
#        [ 54,  56,  52, ..., 233, 234, 230],
#        [ 66,  52,  38, ..., 236, 234, 230],
#        ...,
#        [111, 113, 113, ...,  48,  61,  99],
#        [111, 113, 114, ...,  73,  57, 104],
#        [111, 113, 115, ...,  91,  52,  92]], dtype=uint8), array([[233, 233, 233, ...,  31,  24,  10],
#        [233, 233, 233, ...,  26,  25,  20],
#        [233, 233, 233, ...,  19,  17,  29],
#        ...,
#        [ 59,  45,  52, ...,  24,  18,  18],
#        [ 46,  41,  57, ...,  19,  15,  23],
#        [ 38,  52,  49, ...,  14,  12,  28]], dtype=uint8), array([[ 81,  99,  77, ..., 220, 219, 217],
#        [101,  98,  87, ..., 219, 219, 219],
#        [117,  80,  61, ..., 219, 219, 219],
#        ...,
#        [  2,  16,  20, ...,  20,  14,  16],
#        [ 22,   8,  17, ...,  22,  15,  13],
#        [ 17,   7,  13, ...,  16,  11,   4]], dtype=uint8), array([[178, 178, 178, ...,  16,   9,   7],
#        [178, 178, 177, ...,  20,  16,  12],
#        [179, 177, 177, ...,  13,  10,  14],
#        ...,
#        [133, 117, 151, ...,  10,  32,  18],
#        [124, 146, 133, ...,   5,  22,  29],
#        [160, 147, 102, ...,   7,  11,  25]], dtype=uint8), array([[ 63,  72,  85, ..., 177, 176, 177],
#        [ 85,  96, 108, ..., 177, 177, 177],
#        [109, 119, 129, ..., 177, 176, 176],
#        ...,
#        [161, 160, 162, ...,   8,  13,  15],
#        [150, 151, 150, ...,  10,  14,  18],
#        [145, 141, 143, ...,   9,  15,  15]], dtype=uint8), array([[45, 29, 21, ..., 11, 12, 18],
#        [34, 22, 25, ..., 12, 13, 14],
#        [32, 22, 24, ..., 11, 13, 14],
#        ...,
#        [57, 33, 47, ..., 23, 26, 31],
#        [59, 35, 36, ..., 16, 28, 40],
#        [60, 35, 36, ..., 14, 27, 42]], dtype=uint8), array([[28, 23, 19, ..., 33, 29, 32],
#        [22, 19, 17, ..., 37, 30, 28],
#        [20, 18, 16, ..., 42, 30, 25],
#        ...,
#        [38, 35, 29, ..., 24, 18, 19],
#        [50, 36, 35, ..., 21, 16, 21],
#        [48, 46, 47, ..., 38, 26, 18]], dtype=uint8), array([[  4,   7,   8, ...,  10,  12,  23],
#        [  5,   8,   9, ...,  18,  18,  14],
#        [  5,   8,  10, ...,   8,   4,   1],
#        ...,
#        [239, 237, 244, ...,  31,  26,  34],
#        [248, 243, 239, ...,  33,  27,  30],
#        [252, 246, 234, ...,  33,  28,  32]], dtype=uint8), array([[ 2, 10, 13, ..., 15, 11,  5],
#        [11, 17,  8, ...,  8, 12,  7],
#        [16, 11,  7, ..., 12, 10, 10],
#        ...,
#        [17, 17, 18, ...,  0,  0,  1],
#        [ 3, 11, 14, ...,  0,  1,  3],
#        [ 1,  4, 19, ...,  1,  0,  1]], dtype=uint8), array([[  2,   2,   2, ...,  28,  39,  74],
#        [  4,   4,   2, ...,  24,  21,  17],
#        [  7,   7,   4, ...,  18,  23,  18],
#        ...,
#        [ 48,  51,  89, ..., 228, 244, 244],
#        [ 59,  61,  91, ..., 199, 199, 201],
#        [ 94,  93, 117, ..., 164, 168, 164]], dtype=uint8), array([[146,  77,  44, ...,  51,  34,  27],
#        [103,  69,  47, ...,  80,  46,  20],
#        [ 80,  75,  41, ...,  27,  38,  48],
#        ...,
#        [242, 240, 237, ...,  50,  33,  14],
#        [241, 240, 240, ...,  25,  13,  13],
#        [241, 241, 240, ...,  10,  12,  19]], dtype=uint8), array([[119, 116, 119, ...,   5,   6,   8],
#        [118, 115, 118, ...,   5,   8,  11],
#        [116, 113, 116, ...,   5,   8,   9],
#        ...,
#        [126, 126, 127, ...,  12,  13,  17],
#        [126, 127, 128, ...,  12,   8,   9],
#        [127, 128, 129, ...,  12,   8,   6]], dtype=uint8), array([[ 19,  29,  29, ..., 120, 170, 169],
#        [ 24,  34,  28, ...,  91, 154, 164],
#        [ 26,  34,  28, ...,  65, 126, 157],
#        ...,
#        [ 66,  61, 133, ...,  36,  25,  46],
#        [ 57,  32, 104, ...,  40,  43,  47],
#        [ 54,  37,  62, ...,  38,  46,  42]], dtype=uint8), array([[ 47,  40,  21, ...,   5,   4,   6],
#        [ 46,  31,  43, ...,   5,   3,   6],
#        [ 31,  34,  38, ...,   6,   3,   3],
#        ...,
#        [130, 158, 201, ...,  85, 154, 219],
#        [ 54, 103, 228, ..., 230, 222, 161],
#        [ 47,  99, 200, ..., 158, 197,  90]], dtype=uint8), array([[ 61,  48,  46, ...,  50, 102, 141],
#        [ 47,  49,  35, ...,  65, 103, 106],
#        [ 49,  43,  40, ...,  68, 112, 169],
#        ...,
#        [101, 106, 115, ...,  52,  79,  84],
#        [106, 115, 123, ...,  48,  72,  68],
#        [ 95, 112, 120, ...,  46,  64,  65]], dtype=uint8), array([[ 8,  8,  7, ..., 23, 22, 21],
#        [ 7,  7,  6, ..., 26, 23, 20],
#        [ 7,  6,  6, ..., 24, 25, 25],
#        ...,
#        [ 7, 11,  8, ...,  6, 13,  9],
#        [ 8, 12,  8, ...,  7, 16, 10],
#        [ 9, 13,  9, ...,  6, 14,  7]], dtype=uint8), array([[ 7, 12, 11, ..., 41, 21, 16],
#        [ 9,  5,  6, ..., 22, 46, 16],
#        [ 4,  2,  7, ..., 21, 27, 34],
#        ...,
#        [ 7,  5,  6, ..., 45, 26, 42],
#        [ 5,  6,  3, ..., 43, 27, 50],
#        [ 5,  5,  2, ..., 44, 23, 54]], dtype=uint8), array([[204, 206, 200, ...,  51,  32,  12],
#        [206, 210, 202, ...,  60,  43,  24],
#        [209, 208, 199, ...,  46,  39,  31],
#        ...,
#        [ 12,  11,  12, ...,  17,  13,   8],
#        [ 23,  16,  12, ...,  14,  11,   7],
#        [ 13,   9,   8, ...,  10,  11,   9]], dtype=uint8), array([[ 18,  14,  23, ...,  19,  37, 100],
#        [ 20,  22,  19, ...,  17,  14,  85],
#        [ 25,  28,  22, ...,  16,  12,  47],
#        ...,
#        [ 19,  32,  31, ...,  35,  36,   6],
#        [ 26,  35,  28, ...,  30,  30,   2],
#        [ 32,  37,  23, ...,  21,  20,   1]], dtype=uint8)]
